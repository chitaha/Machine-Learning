# %% [markdown]
# # Matplotlib
#
# - What is matplotlib
# - Types of plots
# - Plotting graphs and subgraphs
# - Adding a graph inside a graph
# - Graph parameters (title, label, legend)
# - Line graphs (line types, color, transparency)
# - Canvas grid and axis range
# - 2D plots (scatter, step, bar, fill_between)
# - Radar Chart, histogram, contour image
# - 3D surface image
# - Pie Chart example

# %% [markdown]
# **Matplotlib** is an open source drawing library which supports rich drawing types
# It is used to draw 2D and 3D graphics.
# You can understand your data easily by visualizing it with the help of matplotlib.
# You can generate plots, histograms, barcharts and many other charts with just a few lines of code.

# %%
from matplotlib import pylab
print(pylab.__version__)
# Out:
# 1.16.5

# %%
# Use numpy to generate random data
import numpy as np
x = np.linspace(0,10,25)
y = x*x+2

# %%
print(x)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]

# %%
print(y)
# Out:
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
print(np.array([x,y]).reshape(25,2))
# Out:
# [[  0.           0.41666667]
#  [  0.83333333   1.25      ]
#  [  1.66666667   2.08333333]
#  [  2.5          2.91666667]
#  [  3.33333333   3.75      ]
#  [  4.16666667   4.58333333]
#  [  5.           5.41666667]
#  [  5.83333333   6.25      ]
#  [  6.66666667   7.08333333]
#  [  7.5          7.91666667]
#  [  8.33333333   8.75      ]
#  [  9.16666667   9.58333333]
#  [ 10.           2.        ]
#  [  2.17361111   2.69444444]
#  [  3.5625       4.77777778]
#  [  6.34027778   8.25      ]
#  [ 10.50694444  13.11111111]
#  [ 16.0625      19.36111111]
#  [ 23.00694444  27.        ]
#  [ 31.34027778  36.02777778]
#  [ 41.0625      46.44444444]
#  [ 52.17361111  58.25      ]
#  [ 64.67361111  71.44444444]
#  [ 78.5625      86.02777778]
#  [ 93.84027778 102.        ]]

# %%
# It only takes one command to draw
pylab.plot(x, y, 'r') #'r' is for red

# %%
# Drawing a subgraph
pylab.subplot(1,2,1) # 1,2,1 - rows, columns, indexes
pylab.plot(x,y,"r--")
pylab.subplot(1,2,2)
pylab.plot(y,x,"g*-")

# %%
# Drawing a subgraph
# pylab.subplot(1,2,1) # 1,2,1 - rows, columns, indexes
pylab.plot(x,y,"r--")
# pylab.subplot(1,2,2)
pylab.plot(y,x,"g*-")

# %%
pylab.subplot(1,2,1)

# %%
pylab.subplot(1,1,1)

# %%
pylab.subplot(2,2,2)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
axis = fig.add_axes([0.5,0.5,0.8,0.8]) # control the left, right, width, height of the canvas
axis.plot(x,y,"r")

# %%
# again we draw subgraphs
fig, axes = plt.subplots(nrows=1, ncols=2) #submap is for 1 row, two columns
for ax in axes:
    ax.plot(x,y,'r')

# %%
# again we draw subgraphs
fig, axes = plt.subplots(nrows=2, ncols=1) #submap is for 1 row, two columns
for ax in axes:
    ax.plot(x,y,'r')

# %%
# we can also draw a picture or graph inside another graph
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.9,0.9])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y,"r")
axes2.plot(y,x,"g")

# %%
fig = plt.figure(figsize=(16,9))
fig.add_subplot()
plt.plot(x,y,"y")

# %%
fig = plt.figure(figsize=(16,9), dpi=600)
fig.add_subplot()
plt.plot(x,y,"y")

# %%
fig = plt.figure(figsize=(16,9), dpi=50)
fig.add_subplot()
plt.plot(x,y,"b")

# %%
fig, axes = plt.subplots()
axes.set_title("TITLE (set_title)")
axes.set_xlabel("X (set_xlabel)")
axes.set_ylabel("Y (set_ylabel)")
axes.plot(x, y, "r")

# %%
#ax.legend(["label1, label2"])
fig, axes = plt.subplots()
axes.set_title("TITLE OF GRAPH")
axes.set_xlabel("X LABEL")
axes.set_ylabel("Y LABEL")
axes.plot(x, x**2)
axes.plot(x, x**3)
axes.plot(x, x**4)

# %%
#ax.legend(["label1, label2"])
fig, axes = plt.subplots()
axes.set_title("TITLE OF GRAPH")
axes.set_xlabel("X LABEL")
axes.set_ylabel("Y LABEL")
axes.plot(x, x**2)
axes.plot(x, x**3)
axes.plot(x, x**4)
axes.legend(["y=x**2", "y=x**3", "y=x**4"], loc=2)

# %%
fig, axes = plt.subplots()
axes.set_title("TITLE OF GRAPH")
axes.set_xlabel("X LABEL")
axes.set_ylabel("Y LABEL")
axes.plot(x, x**2)
axes.plot(x, x**3)
axes.plot(x, x**4)
axes.legend(["y=x**2", "y=x**3", "y=x**4"], loc=6)

# %%
# In matplotlib, you can set other properties such as line color, transparency and more
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color="red")
axes.plot(x, x+2, color="blue")
axes.plot(x, x+3, color="green")

# %%
# In matplotlib, you can set other properties such as line color, transparency(alpha) and more
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color="red", alpha=0.3)
axes.plot(x, x+2, color="red", alpha=0.5)
axes.plot(x, x+3, color="red", alpha=0.8)

# %%
# In matplotlib, you can set other properties such as line color, transparency and more
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color="blue", linewidth=1)
axes.plot(x, x+2, color="blue", linewidth=2)
axes.plot(x, x+3, color="blue", linewidth=3)
axes.plot(x, x+4, color="blue", linewidth=4)

# %%
# In matplotlib, you can set other properties such as line color, transparency and more
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color="green", linestyle="solid")
axes.plot(x, x+2, color="green", linestyle="dashed")
axes.plot(x, x+3, color="green", linestyle="dashdot")
axes.plot(x, x+4, color="green", linestyle="dotted")

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color="green", linestyle="solid")
axes.plot(x, x+2, color="green", linestyle="dashed")
axes.plot(x, x+3, color="green", linestyle="dashdot")
axes.plot(x, x+4, color="green", linestyle="dotted")
axes.legend(["y=x+1", "y=x+2", "y=x+3", "y=x+4"])

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color="green", linestyle="solid")
axes.plot(x, x+2, color="green", linestyle="dashdot")
axes.plot(x, x+3, color="green", linestyle="dotted")
line, = axes.plot(x, x+4, color="black", linestyle="dashed")
line.set_dashes([5,10,15,10])
line, = axes.plot(x, x+5, color="black", linestyle="dashed")
line.set_dashes([6,1,4,2])
line, = axes.plot(x, x+6, color="black", linestyle="dashed")
line.set_dashes([3,6,8,6])
axes.legend(["y=x+1", "y=x+2", "y=x+3", "y=x+4", "y=x+5", "y=x+6"])

# %%
fig, ax = plt.subplots(dpi=150)
ax.plot(x, x*1, marker="o")
ax.plot(x, x*2, marker="p")
ax.plot(x, x*3, marker="x")
ax.plot(x, x*4, marker="s")
ax.plot(x, x*5, marker="*")

# %%
fig, ax = plt.subplots(dpi=150)
ax.plot(x, x+1, color="black", marker="o", markersize=3, markerfacecolor="blue")
ax.plot(x, x+2, color="black", marker="p", markersize=4, markerfacecolor="green")
ax.plot(x, x+3, color="black", marker="x", markersize=5, markerfacecolor="yellow")
ax.plot(x, x+4, color="black", marker="s", markersize=6, markerfacecolor="purple")
ax.plot(x, x+5, color="black", marker="*", markersize=7, markerfacecolor="red")

# %%
# set the canvas grid and axis range
fig, axes = plt.subplots(1,2, figsize=(10,5))
axes[0].plot(x, x**2, x, x**3)
axes[0].grid(True)
axes[0].legend(["y=x**2", "y=x**3"])

axes[1].plot(x, x**2, x, x**3)
axes[1].grid(False)
axes[1].legend(["y=x**2", "y=x**3"])

# %%
# set the canvas grid and axis range
fig, axes = plt.subplots(1,2, figsize=(10,5))
axes[0].plot(x, x**2, x, x**3)
axes[0].grid(True)
axes[0].legend(["y=x**2", "y=x**3"])

axes[1].plot(x, x**2, x, x**3)
axes[1].grid(False)
axes[1].legend(["y=x**2", "y=x**3"])
axes[1].set_xlim(0,60)
axes[1].set_ylim(0,60)
# Out:
# (0, 60)

# %%
# set the canvas grid and axis range
fig, axes = plt.subplots(1,2, figsize=(10,5))
axes[0].plot(x, x**2, x, x**3)
axes[0].grid(True)
axes[0].legend(["y=x**2", "y=x**3"])

axes[1].plot(x, x**2, x, x**3)
axes[1].grid(False)
axes[1].legend(["y=x**2", "y=x**3"])
axes[1].set_xlim(0, 20)
axes[1].set_ylim(20, 80)
# Out:
# (20, 80)

# %%
# set the canvas grid and axis range
fig, axes = plt.subplots(1,2, figsize=(10,5))
axes[0].plot(x, x**2, x, x**3)
axes[0].grid(True)
axes[0].legend(["y=x**2", "y=x**3"])

axes[1].plot(x, x**2, x, x**3)
axes[1].grid(True)
axes[1].legend(["y=x**2", "y=x**3"])
axes[1].set_xlim(0, 20)
axes[1].set_ylim(20, 80)
# Out:
# (20, 80)

# %% [markdown]
# # Other 2D graphics

# %%
fig, axes = plt.subplots(2, 4, figsize=(16,9))

# %%
n = np.array([1,2,3,4,5])
fig, axes = plt.subplots(1, 4, figsize=(16,9))
axes[0].set_title("Scatter")
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))

axes[1].set_title("Step")
axes[1].step(n, n**2)

axes[2].set_title("Bar")
axes[2].bar(n, n**2, align="center", width=0.5)

axes[3].set_title("Fill between")
axes[3].fill_between(x, x**2, x**3, color="green")

# %%
# Draw a radar chart
fig = plt.figure(figsize=(8,8))
ax = fig.add_axes([0.0,0.0,1,1], polar=True)

# %%
# Draw a radar chart
fig = plt.figure(figsize=(8,8))
ax = fig.add_axes([0.0,0.0,0.6,0.6], polar=True)

# %%
# Draw a radar chart
fig = plt.figure(figsize=(8,8))
ax = fig.add_axes([0.0,0.0,0.5,0.5], polar=True)
t = np.linspace(0, 2*np.pi, 100)
ax.plot(t,t*5,color="blue")

# %%
# draw a histogram
n = np.random.randn(10000)
fig, axes = plt.subplots(1, 2, figsize=(16,9))
axes[0].set_title("Default Histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative Detailed Histogram")
axes[1].hist(n, cumulative=True, bins=50)
# Out:
# (array([1.000e+00, 1.000e+00, 3.000e+00, 5.000e+00, 1.000e+01, 1.300e+01,
#         1.900e+01, 3.800e+01, 5.500e+01, 8.500e+01, 1.170e+02, 1.680e+02,
#         2.440e+02, 3.450e+02, 4.700e+02, 6.150e+02, 8.260e+02, 1.053e+03,
#         1.369e+03, 1.685e+03, 2.082e+03, 2.511e+03, 2.992e+03, 3.537e+03,
#         4.121e+03, 4.708e+03, 5.257e+03, 5.844e+03, 6.414e+03, 6.914e+03,
#         7.401e+03, 7.838e+03, 8.238e+03, 8.599e+03, 8.919e+03, 9.192e+03,
#         9.392e+03, 9.561e+03, 9.677e+03, 9.765e+03, 9.837e+03, 9.897e+03,
#         9.929e+03, 9.955e+03, 9.975e+03, 9.988e+03, 9.995e+03, 9.998e+03,
#         9.999e+03, 1.000e+04]),
#  array([-3.85985297, -3.7141699 , -3.56848684, -3.42280378, -3.27712072,
#         -3.13143766, -2.9857546 , -2.84007154, -2.69438848, -2.54870542,
#         -2.40302236, -2.2573393 , -2.11165624, -1.96597318, -1.82029012,
#         -1.67460705, -1.52892399, -1.38324093, -1.23755787, -1.09187481,
# ...

# %%
# draw a histogram
n = np.random.randn(10000)
fig, axes = plt.subplots(1, 2, figsize=(16,9))
axes[0].set_title("Default Histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative Detailed Histogram")
axes[1].hist(n, cumulative=True, bins=20)
# Out:
# (array([2.000e+00, 4.000e+00, 1.700e+01, 3.900e+01, 1.420e+02, 3.720e+02,
#         8.390e+02, 1.620e+03, 2.796e+03, 4.269e+03, 5.870e+03, 7.270e+03,
#         8.481e+03, 9.276e+03, 9.673e+03, 9.875e+03, 9.962e+03, 9.990e+03,
#         9.998e+03, 1.000e+04]),
#  array([-4.23781679, -3.83488129, -3.43194579, -3.02901029, -2.62607479,
#         -2.22313929, -1.82020379, -1.41726829, -1.01433279, -0.61139729,
#         -0.2084618 ,  0.1944737 ,  0.5974092 ,  1.0003447 ,  1.4032802 ,
#          1.8062157 ,  2.2091512 ,  2.6120867 ,  3.0150222 ,  3.4179577 ,
#          3.8208932 ]),
#  <a list of 20 Patch objects>)

# %%
# draw a histogram
n = np.random.randn(10000)
fig, axes = plt.subplots(1, 2, figsize=(16,9))
axes[0].set_title("Default Histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative Detailed Histogram")
axes[1].hist(n, bins=20)
# Out:
# (array([   2.,    4.,   14.,   37.,  103.,  229.,  519.,  811., 1200.,
#         1486., 1536., 1431., 1173.,  720.,  432.,  182.,   83.,   18.,
#           17.,    3.]),
#  array([-4.09881691, -3.70368268, -3.30854846, -2.91341424, -2.51828002,
#         -2.1231458 , -1.72801158, -1.33287736, -0.93774314, -0.54260892,
#         -0.1474747 ,  0.24765952,  0.64279374,  1.03792797,  1.43306219,
#          1.82819641,  2.22333063,  2.61846485,  3.01359907,  3.40873329,
#          3.80386751]),
#  <a list of 20 Patch objects>)

# %%
# draw a contour image
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2-Y**2)
Z2 = np.exp(-(X-1)**2-(Y-1)**2)
Z = (Z1-Z2)*2
print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax = plt.subplots(figsize=(9,6))
CS = ax.contour(X,Y,Z)
ax.clabel(CS, inline=1, fontsize=10)
ax.set_title("Contour Map")
# Out:
# Text(0.5, 1.0, 'Contour Map')

# %%
# draw 3D surface image
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))

# specify the 3D graphics to draw with projection = "3d"
ax = fig.add_subplot(1,2,1, projection="3d")
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %%
# draw 3D surface image
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))

# specify the 3D graphics to draw with projection = "3d"
ax = fig.add_subplot(1,1,1, projection="3d")
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %%
# heatmap
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Define numbers of generated data points and bins per axis.
N_numbers = 100000
N_bins = 100

# set random seed 
np.random.seed(0)

# Generate 2D normally distributed numbers.
x, y = np.random.multivariate_normal(
        mean=[0.0, 0.0],      # mean
        cov=[[1.0, 0.4],
             [0.4, 0.25]],    # covariance matrix
        size=N_numbers
        ).T                   # transpose to get columns


# Construct 2D histogram from data using the 'plasma' colormap
plt.hist2d(x, y, bins=N_bins, density=False, cmap='plasma')

# Plot a colorbar with label.
cb = plt.colorbar()
cb.set_label('Number of entries')

# Add title and labels to plot.
plt.title('Heatmap of 2D normally distributed data points')
plt.xlabel('x axis')
plt.ylabel('y axis')

# Show the plot.
plt.show()

# %% [markdown]
# # Pie chart of popularity of programming languages

# %%
import matplotlib.pyplot as plt

# data to plot
languages = "Python", "Java", "PHP", "JavaScript", "C#", "C++"
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.pie(popularity, labels=languages)
# Out:
# ([<matplotlib.patches.Wedge at 0x29cfa926d30>,
# ...
#  [Text(0.6106212455488447, 0.914954476727874, 'Python'),
#   Text(-1.0139237282141302, 0.42656614184011216, 'Java'),
#   Text(-0.7897694469856671, -0.7656789278855424, 'PHP'),
#   Text(-0.06323929665114071, -1.0981806733680344, 'JavaScript'),
#   Text(0.654413852726294, -0.8841620379545417, 'C#'),
#   Text(1.0520142924916651, -0.3213501647630839, 'C++')])

# %%
# explode python
explode = [0.1, 0,0,0,0,0,]
plt.pie(popularity, explode=explode, labels=languages, shadow=True, autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x29cfa804ac8>,
# ...
#  [Text(0.666132267871467, 0.998132156430408, 'Python'),
#   Text(-1.0139237282141302, 0.42656614184011216, 'Java'),
#   Text(-0.7897694469856671, -0.7656789278855424, 'PHP'),
#   Text(-0.06323929665114071, -1.0981806733680344, 'JavaScript'),
#   Text(0.654413852726294, -0.8841620379545417, 'C#'),
#   Text(1.0520142924916651, -0.3213501647630839, 'C++')],
#  [Text(0.38857715625835565, 0.582243757917738, '31.3%'),
#   Text(-0.5530493062986165, 0.23267244100369752, '24.8%'),
#   Text(-0.43078333471945474, -0.41764305157393217, '12.4%'),
#   Text(-0.03449416180971311, -0.5990076400189277, '11.3%'),
#   Text(0.35695301057797857, -0.48227020252065905, '10.8%'),
#   Text(0.5738259777227264, -0.1752819080525912, '9.4%')])
