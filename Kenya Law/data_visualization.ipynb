# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("kenya-law.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  number                                            Parties  \
# 0           0       0  REPUBLIC vs THE CHIEF OF GENERAL STAFF ARMED F...
# 1           1       1    Hans Raj Aggarwal v Munshiram & Company Limited
# 2           2       2  ELIZABETH NGELELE,JOHN MULI MUNYAO,KIOKO MBULA...
# 3           3       4      CATHERINE KARUNGARI KARL vs GUENTER OTTO KARL
# 4           4       5  Dominic Charles Muthuuri v National Industrial...
#
#   Date Delivered Case Class                                        Court  \
# 0      24-Feb-98      Civil  High Court at Nairobi (Milimani Law Courts)
# 1       5-May-00      Civil                   Court of Appeal at Nairobi
# 2      13-May-98   Criminal                   Court of Appeal at Nairobi
# 3       8-May-98      Civil                   Court of Appeal at Nairobi
# 4      10-Mar-03      Civil  High Court at Nairobi (Milimani Law Courts)
#
#   Case Action                                             Judges
# 0         NaN                          Amraphael Mbogholi-Msagha
# 1    Judgment  Johnson Evan Gicheru, Akilano Molade Akiwumi, ...
# 2    Judgment        Akilano Molade Akiwumi, Philip Kiptoo Tunoi
# 3         NaN                             Akilano Molade Akiwumi
# 4    Judgment                                    Aaron G Ringera

# %%
# Drop the rows where all elements are missing.
df = df.dropna(how='all')

# %%
#Define in which columns to look for missing values:
df = df.dropna(subset=['Parties'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29097 entries, 0 to 29096
# Data columns (total 8 columns):
# Unnamed: 0        29097 non-null int64
# number            29097 non-null int64
# Parties           29097 non-null object
# Date Delivered    29097 non-null object
# Case Class        29096 non-null object
# Court             29090 non-null object
# Case Action       19754 non-null object
# Judges            28625 non-null object
# dtypes: int64(2), object(6)
# memory usage: 2.0+ MB

# %%
df = df.drop(columns = ["number"])

# %%
df.head()
# Out:
#                                              Parties Date Delivered  \
# 0  REPUBLIC vs THE CHIEF OF GENERAL STAFF ARMED F...      24-Feb-98
# 1    Hans Raj Aggarwal v Munshiram & Company Limited       5-May-00
# 2  ELIZABETH NGELELE,JOHN MULI MUNYAO,KIOKO MBULA...      13-May-98
# 3      CATHERINE KARUNGARI KARL vs GUENTER OTTO KARL       8-May-98
# 4  Dominic Charles Muthuuri v National Industrial...      10-Mar-03
#
#   Case Class                                        Court Case Action  \
# 0      Civil  High Court at Nairobi (Milimani Law Courts)         NaN
# 1      Civil                   Court of Appeal at Nairobi    Judgment
# 2   Criminal                   Court of Appeal at Nairobi    Judgment
# 3      Civil                   Court of Appeal at Nairobi         NaN
# 4      Civil  High Court at Nairobi (Milimani Law Courts)    Judgment
#
#                                               Judges
# 0                          Amraphael Mbogholi-Msagha
# 1  Johnson Evan Gicheru, Akilano Molade Akiwumi, ...
# 2        Akilano Molade Akiwumi, Philip Kiptoo Tunoi
# 3                             Akilano Molade Akiwumi
# 4                                    Aaron G Ringera

# %%
df.to_csv("kenya-law.csv")

# %%
df.describe()
# Out:
#                    Parties Date Delivered Case Class  \
# count                29097          29097      29096
# unique               27194           4742          3
# top     Kariuki v Republic      30-Oct-09      Civil
# freq                     7             81      20823
#
#                                               Court Case Action  \
# count                                         29090       19754
# unique                                           34          13
# top     High Court at Nairobi (Milimani Law Courts)      Ruling
# freq                                           8823       10039
#
#                        Judges
# count                   28625
# unique                   1438
# top     Luka Kiprotich Kimaru
# freq                      880

# %%
df.groupby(by="Judges")

# %%
df.head()
# Out:
#                                              Parties Date Delivered  \
# 0  REPUBLIC vs THE CHIEF OF GENERAL STAFF ARMED F...      24-Feb-98
# 1    Hans Raj Aggarwal v Munshiram & Company Limited       5-May-00
# 2  ELIZABETH NGELELE,JOHN MULI MUNYAO,KIOKO MBULA...      13-May-98
# 3      CATHERINE KARUNGARI KARL vs GUENTER OTTO KARL       8-May-98
# 4  Dominic Charles Muthuuri v National Industrial...      10-Mar-03
#
#   Case Class                                        Court Case Action  \
# 0      Civil  High Court at Nairobi (Milimani Law Courts)         NaN
# 1      Civil                   Court of Appeal at Nairobi    Judgment
# 2   Criminal                   Court of Appeal at Nairobi    Judgment
# 3      Civil                   Court of Appeal at Nairobi         NaN
# 4      Civil  High Court at Nairobi (Milimani Law Courts)    Judgment
#
#                                               Judges
# 0                          Amraphael Mbogholi-Msagha
# 1  Johnson Evan Gicheru, Akilano Molade Akiwumi, ...
# 2        Akilano Molade Akiwumi, Philip Kiptoo Tunoi
# 3                             Akilano Molade Akiwumi
# 4                                    Aaron G Ringera
